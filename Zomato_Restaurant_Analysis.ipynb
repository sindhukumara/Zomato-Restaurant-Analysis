# %%
print("hello sindhuja")
# Out:
# hello sindhuja

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("All libraries loaded sucessfully")
# Out:
# All libraries loaded sucessfully

# %%
import pandas as pd
df = pd.read_csv("../data/Zomato-data-.csv")
df.head()
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
df.shape
# Out:
# (148, 7)

# %%
df.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'votes',
#        'approx_cost(for two people)', 'listed_in(type)'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    str
#  1   online_order                 148 non-null    str
#  2   book_table                   148 non-null    str
#  3   rate                         148 non-null    str
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    str
# dtypes: int64(2), str(5)
# memory usage: 8.2 KB

# %%
df.isnull().sum()
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# approx_cost(for two people)    0
# listed_in(type)                0
# dtype: int64

# %%
df[['listed_in(type)'].value_counts()
# Out:
#   Cell In[9], line 1
#     df[['listed_in(type)'].value_counts()
#                                          ^
# _IncompleteInputError: incomplete input

# %%
df['listed_in(type)'].value_counts()
# Out:
# listed_in(type)
# Dining    110
# Cafes      23
# other       8
# Buffet      7
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

df['listed_in(type)'].value_counts().plot(kind='bar')

plt.title("Restaurant Types")
plt.xlabel("Type")
plt.ylabel("Count")

plt.show()

# %%
df['online_order'].value_counts()
# Out:
# online_order
# No     90
# Yes    58
# Name: count, dtype: int64

# %%
df['online_order'].value_counts().plot(kind='pie', autopct='%1.1f%%')

plt.title("Online Orders")
plt.show()

# %%
df.sort_values(by='votes', ascending=False).head(10)
# Out:
#                   name online_order book_table   rate  votes  \
# 38   Empire Restaurant          Yes         No  4.4/5   4884
# 86       Meghana Foods          Yes         No  4.4/5   4401
# 7               Onesta          Yes        Yes  4.6/5   2556
# 44              Onesta          Yes        Yes  4.6/5   2556
# 65         Kabab Magic          Yes         No  4.1/5   1720
# 37     Szechuan Dragon          Yes         No  4.2/5   1647
# 54        Roving Feast           No         No  4.0/5   1047
# 2      San Churro Cafe          Yes         No  3.8/5    918
# 14     San Churro Cafe          Yes         No  3.8/5    918
# 67  Gustoes Beer House           No         No  4.1/5    868
#
#     approx_cost(for two people) listed_in(type)
# 38                          750           other
# 86                          600          Dining
# 7                           600           Cafes
# 44                          600           other
# 65                          400          Dining
# ...

# %%
df.sort_values(by='votes', ascending=False).head(10)
# Out:
#                   name online_order book_table   rate  votes  \
# 38   Empire Restaurant          Yes         No  4.4/5   4884
# 86       Meghana Foods          Yes         No  4.4/5   4401
# 7               Onesta          Yes        Yes  4.6/5   2556
# 44              Onesta          Yes        Yes  4.6/5   2556
# 65         Kabab Magic          Yes         No  4.1/5   1720
# 37     Szechuan Dragon          Yes         No  4.2/5   1647
# 54        Roving Feast           No         No  4.0/5   1047
# 2      San Churro Cafe          Yes         No  3.8/5    918
# 14     San Churro Cafe          Yes         No  3.8/5    918
# 67  Gustoes Beer House           No         No  4.1/5    868
#
#     approx_cost(for two people) listed_in(type)
# 38                          750           other
# 86                          600          Dining
# 7                           600           Cafes
# 44                          600           other
# 65                          400          Dining
# ...

# %%
df.info()
df.isnull().sum()
df['listed_in(type)'].value_counts()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    str
#  1   online_order                 148 non-null    str
#  2   book_table                   148 non-null    str
#  3   rate                         148 non-null    str
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    str
# dtypes: int64(2), str(5)
# memory usage: 8.2 KB
# listed_in(type)
# Dining    110
# Cafes      23
# other       8
# Buffet      7
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

restaurant_types = df['listed_in(type)'].value_counts()

restaurant_types.plot(kind='bar')

plt.title("Distribution of Restaurant Types")
plt.xlabel("Restaurant Type")
plt.ylabel("Number of Restaurants")

plt.show()

# %%
df['online_order'].value_counts()
# Out:
# online_order
# No     90
# Yes    58
# Name: count, dtype: int64

# %%
df['book_table'].value_counts()
# Out:
# book_table
# No     140
# Yes      8
# Name: count, dtype: int64

# %%
df.sort_values(by='votes',ascending=False)
[['name','votes']].head(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 2
#       1 df.sort_values(by='votes',ascending=False)
# ----> 2 [['name','votes']].head(10)
#
# AttributeError: 'list' object has no attribute 'head'

# %%
df.sort_values(by='votes',ascending=False) [['name','votes']].head(10)
# Out:
#                   name  votes
# 38   Empire Restaurant   4884
# 86       Meghana Foods   4401
# 7               Onesta   2556
# 44              Onesta   2556
# 65         Kabab Magic   1720
# 37     Szechuan Dragon   1647
# 54        Roving Feast   1047
# 2      San Churro Cafe    918
# 14     San Churro Cafe    918
# 67  Gustoes Beer House    868

# %%
df['rating_numeric'] = df['rate'].str.split('/').str[0].astype(float)

df.groupby('listed_in(type)')['rating_numeric'].mean()
# Out:
# listed_in(type)
# Buffet    3.842857
# Cafes     3.765217
# Dining    3.571818
# other     3.912500
# Name: rating_numeric, dtype: float64

# %%
df.groupby('online_order')['rating_numeric'].mean()
df.groupby('book_table')['rating_numeric'].mean()
# Out:
# book_table
# No     3.601429
# Yes    4.187500
# Name: rating_numeric, dtype: float64
